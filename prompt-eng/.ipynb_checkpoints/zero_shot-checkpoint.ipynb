# %% [markdown]
# # Zero-Shot Prompting
#
# Zero-shot prompting refers to a technique in prompt engineering where you provide a model with a task without any prior examples. The model is expected to understand and generate a response or complete the task purely based on the given instruction.
#
# In other words, the model is given "zero" prior training examples or demonstrations in the prompt and relies on its pre-trained knowledge to infer what is needed.
#
# ## References:
# * [Wei et al. (2022)](https://arxiv.org/pdf/2109.01652.pdf): demonstrate how instruction tuning improves zero-shot learning

# %% [markdown]
# ## Running this code on MyBind.org
#
# Note: remember that you will need to **adjust CONFIG** with **proper URL and API_KEY**!
#
# [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/GenILab-FAU/prompt-eng/HEAD?urlpath=%2Fdoc%2Ftree%2Fprompt-eng%2Fzero_shot.ipynb)

# %%
##
## ZERO SHOT PROMPTING
##

from _pipeline import create_payload, model_req

#### (1) Adjust the inbounding  Prompt, simulating inbounding requests from users or other systems
MESSAGE = "create a SDLC requirements document focused on machine learning models"

#### (2) Adjust the Prompt Engineering Technique to be applied, simulating Workflow Templates
PROMPT = MESSAGE 

#### (3) Configure the Model request, simulating Workflow Orchestration
# Documentation: https://github.com/ollama/ollama/blob/main/docs/api.md
payload = create_payload(target="ollama",
                         model="llama3", 
                         prompt=PROMPT, 
                         temperature=1, 
                         num_ctx=100, 
                         num_predict=2000)

### YOU DONT NEED TO CONFIGURE ANYTHING ELSE FROM THIS POINT
# Send out to the model
time, response = model_req(payload=payload)
print(response)
if time: print(f'Time taken: {time}s')
# Out:
# {'model': 'llama3', 'prompt': 'create a SDLC requirements document focused on machine learning models', 'stream': False, 'options': {'temperature': 1, 'num_ctx': 100, 'num_predict': 2000}}
# **Machine Learning Model Development Life Cycle (MLMDLC) Requirements Document**
#
# **Introduction:**
# The Machine Learning Model Development Life Cycle (MLMDLC) is designed to ensure the development of high-quality, reliable, and scalable machine learning models that meet business requirements. This document outlines the requirements for developing, deploying, and maintaining machine learning models within our organization.
#
# **Scope:**
#
# * The MLMD (Machine Learning Model Development) process applies to all machine learning models developed within our organization.
# * This process covers the development of new machine learning models, as well as updates and maintenance of existing models.
#
# **I. Introduction**
#
# ...

# %%
##
## ZERO SHOT PROMPTING
##

from _pipeline import create_payload, model_req

#### (1) Adjust the inbounding  Prompt, simulating inbounding requests from users or other systems
MESSAGE = "create a SDLC requirements document focused on machine learning models"

#### (2) Adjust the Prompt Engineering Technique to be applied, simulating Workflow Templates
PROMPT = MESSAGE 

#### (3) Configure the Model request, simulating Workflow Orchestration
# Documentation: https://github.com/ollama/ollama/blob/main/docs/api.md
payload = create_payload(target="ollama",
                         model="llama3", 
                         prompt=PROMPT, 
                         temperature=1.33, 
                         num_ctx=100, 
                         num_predict=2000)

### YOU DONT NEED TO CONFIGURE ANYTHING ELSE FROM THIS POINT
# Send out to the model
time, response = model_req(payload=payload)
print(response)
if time: print(f'Time taken: {time}s')
# Out:
# {'model': 'llama3', 'prompt': 'create a SDLC requirements document focused on machine learning models', 'stream': False, 'options': {'temperature': 1.33, 'num_ctx': 100, 'num_predict': 2000}}
# **Machine Learning Models SDLC Requirements Document**
#
# **Introduction:**
# The purpose of this document is to outline the Software Development Life Cycle (SDLC) requirements for machine learning (ML) models, specifically focusing on developing and deploying predictive analytics models. This document provides a framework for ensuring that ML models are developed, tested, and deployed in a controlled and transparent manner.
#
# **Scope:**
# This SDLC (Software Development Life Cycle) requirements document focuses on the development and deployment of machine learning models using popular open-source frameworks such as TensorFlow, PyTorch, or Scikit-Learn. This document outlines the essential requirements for building robust, reliable, and maintainable machine learning models.
#
# **Scope**
#
# ...

# %%
##
## ZERO SHOT PROMPTING
##

from _pipeline import create_payload, model_req

#### (1) Adjust the inbounding  Prompt, simulating inbounding requests from users or other systems
MESSAGE = "create a SDLC requirements document focused on machine learning models"

#### (2) Adjust the Prompt Engineering Technique to be applied, simulating Workflow Templates
PROMPT = MESSAGE 

#### (3) Configure the Model request, simulating Workflow Orchestration
# Documentation: https://github.com/ollama/ollama/blob/main/docs/api.md
payload = create_payload(target="ollama",
                         model="llama3", 
                         prompt=PROMPT, 
                         temperature=1.66, 
                         num_ctx=100, 
                         num_predict=2000)

### YOU DONT NEED TO CONFIGURE ANYTHING ELSE FROM THIS POINT
# Send out to the model
time, response = model_req(payload=payload)
print(response)
if time: print(f'Time taken: {time}s')
# Out:
# {'model': 'llama3', 'prompt': 'create a SDLC requirements document focused on machine learning models', 'stream': False, 'options': {'temperature': 1.66, 'num_ctx': 100, 'num_predict': 2000}}
# Here is a sample SDLC (Software Development Life Cycle) Requirements Document for Machine Learning Models:
#
# **Introduction**
#
# The purpose of this document is to outline the Software Development Life Cycle (SDLC) requirements for developing and deploying machine learning models. This document serves as a guide for the development team, ensuring that all necessary steps are taken to develop high-quality machine learning models that meet business objectives.
#
# **Scope**
#
# ...

# %%
##
## ZERO SHOT PROMPTING
##

from _pipeline import create_payload, model_req

#### (1) Adjust the inbounding  Prompt, simulating inbounding requests from users or other systems
MESSAGE = "create a SDLC requirements document focused on machine learning models"

#### (2) Adjust the Prompt Engineering Technique to be applied, simulating Workflow Templates
PROMPT = MESSAGE 

#### (3) Configure the Model request, simulating Workflow Orchestration
# Documentation: https://github.com/ollama/ollama/blob/main/docs/api.md
payload = create_payload(target="ollama",
                         model="llama3", 
                         prompt=PROMPT, 
                         temperature=1.99, 
                         num_ctx=100, 
                         num_predict=2000)

### YOU DONT NEED TO CONFIGURE ANYTHING ELSE FROM THIS POINT
# Send out to the model
time, response = model_req(payload=payload)
print(response)
if time: print(f'Time taken: {time}s')
# Out:
# {'model': 'llama3', 'prompt': 'create a SDLC requirements document focused on machine learning models', 'stream': False, 'options': {'temperature': 1.99, 'num_ctx': 100, 'num_predict': 2000}}
# Here is a sample SDLC (Software Development Life Cycle) Requirements Document focused on Machine Learning Models:
#
# **Machine Learning Model SDLC Requirements**
#
# **Introduction:**
# This SDLC Requirements Document outlines the requirements and guidelines for developing and deploying machine learning models in our organization. The goal of this document is to provide a standardized framework for ensuring that machine learning models are developed, tested, and deployed with quality, security, and compliance in mind.
#
# **Machine Learning Model SDLC Requirements**
#
# **Scope:**
#
# This document applies to all machine learning model development and deployment activities within [Organization Name], including but not limited to:
#
# * Data scientists and engineers
# ...

# %%
##
## ZERO SHOT PROMPTING
##

from _pipeline import create_payload, model_req

#### (1) Adjust the inbounding  Prompt, simulating inbounding requests from users or other systems
MESSAGE = "create a SDLC requirements document focused on machine learning models"

#### (2) Adjust the Prompt Engineering Technique to be applied, simulating Workflow Templates
PROMPT = MESSAGE 

#### (3) Configure the Model request, simulating Workflow Orchestration
# Documentation: https://github.com/ollama/ollama/blob/main/docs/api.md
payload = create_payload(target="ollama",
                         model="llama3", 
                         prompt=PROMPT, 
                         temperature=1, 
                         num_ctx=1000, 
                         num_predict=2000)

### YOU DONT NEED TO CONFIGURE ANYTHING ELSE FROM THIS POINT
# Send out to the model
time, response = model_req(payload=payload)
print(response)
if time: print(f'Time taken: {time}s')
# Out:
# {'model': 'llama3', 'prompt': 'create a SDLC requirements document focused on machine learning models', 'stream': False, 'options': {'temperature': 1, 'num_ctx': 1000, 'num_predict': 2000}}
# Here is a sample SDLC (Software Development Life Cycle) Requirements Document focused on Machine Learning Models:
#
# **Document Title:** Machine Learning Model SDLC Requirements Document
#
# **Version:** 1.0
#
# **Date:** [Current Date]
#
# **Purpose:**
#
# This document outlines the requirements for developing and deploying machine learning models within our organization. The purpose of this document is to ensure that all machine learning projects follow a consistent and rigorous process, from data preparation to model deployment.
#
# **Scope:**
#
# This document applies to all machine learning projects undertaken by [Your Organization]. It covers the development, testing, and deployment of machine learning models used for various applications, including but not limited to:
#
# ...

# %%
##
## ZERO SHOT PROMPTING
##

from _pipeline import create_payload, model_req

#### (1) Adjust the inbounding  Prompt, simulating inbounding requests from users or other systems
MESSAGE = "create a SDLC requirements document focused on machine learning models"

#### (2) Adjust the Prompt Engineering Technique to be applied, simulating Workflow Templates
PROMPT = MESSAGE 

#### (3) Configure the Model request, simulating Workflow Orchestration
# Documentation: https://github.com/ollama/ollama/blob/main/docs/api.md
payload = create_payload(target="ollama",
                         model="llama3", 
                         prompt=PROMPT, 
                         temperature=1.33, 
                         num_ctx=1000, 
                         num_predict=2000)

### YOU DONT NEED TO CONFIGURE ANYTHING ELSE FROM THIS POINT
# Send out to the model
time, response = model_req(payload=payload)
print(response)
if time: print(f'Time taken: {time}s')
# Out:
# {'model': 'llama3', 'prompt': 'create a SDLC requirements document focused on machine learning models', 'stream': False, 'options': {'temperature': 1.33, 'num_ctx': 1000, 'num_predict': 2000}}
# **Machine Learning Model Development Requirements Document**
#
# **Introduction**
#
# This document outlines the Software Development Life Cycle (SDLC) requirements for developing machine learning (ML) models. The goal is to provide a structured approach for building, testing, and deploying ML models that meet business objectives and technical standards.
#
# **Scope**
#
# The scope of this SDLC includes the development, testing, and deployment of ML models for predictive analytics, recommendation systems, natural language processing, computer vision, and other AI/ML applications. The scope does not include traditional software development projects.
#
# **Requirements Gathering**
#
# ...

# %%
##
## ZERO SHOT PROMPTING
##

from _pipeline import create_payload, model_req

#### (1) Adjust the inbounding  Prompt, simulating inbounding requests from users or other systems
MESSAGE = "create a SDLC requirements document focused on machine learning models"

#### (2) Adjust the Prompt Engineering Technique to be applied, simulating Workflow Templates
PROMPT = MESSAGE 

#### (3) Configure the Model request, simulating Workflow Orchestration
# Documentation: https://github.com/ollama/ollama/blob/main/docs/api.md
payload = create_payload(target="ollama",
                         model="llama3", 
                         prompt=PROMPT, 
                         temperature=1.66, 
                         num_ctx=1000, 
                         num_predict=2000)

### YOU DONT NEED TO CONFIGURE ANYTHING ELSE FROM THIS POINT
# Send out to the model
time, response = model_req(payload=payload)
print(response)
if time: print(f'Time taken: {time}s')
# Out:
# {'model': 'llama3', 'prompt': 'create a SDLC requirements document focused on machine learning models', 'stream': False, 'options': {'temperature': 1.66, 'num_ctx': 1000, 'num_predict': 2000}}
# **Machine Learning Models Requirements Document**
#
# **Overview**
#
# This document outlines the requirements for developing and deploying machine learning (ML) models within [Organization Name]. The purpose of this document is to provide a comprehensive guide for ensuring the development, testing, deployment, and maintenance of ML models meet the organization's needs and regulatory requirements.
#
# **Scope**
#
# The scope of this document includes:
#
# 1. Machine Learning Models: Any model developed or deployed using machine learning techniques.
# 2. Data Science Team: The team responsible for developing, testing, and deploying ML models.
#
# **Functional Requirements**
#
# ### 1. Model Development
#
# 1.1. **Model Types**: Support development of the following ML model types:
# ...

# %%
##
## ZERO SHOT PROMPTING
##

from _pipeline import create_payload, model_req

#### (1) Adjust the inbounding  Prompt, simulating inbounding requests from users or other systems
MESSAGE = "create a SDLC requirements document focused on machine learning models"

#### (2) Adjust the Prompt Engineering Technique to be applied, simulating Workflow Templates
PROMPT = MESSAGE 

#### (3) Configure the Model request, simulating Workflow Orchestration
# Documentation: https://github.com/ollama/ollama/blob/main/docs/api.md
payload = create_payload(target="ollama",
                         model="llama3", 
                         prompt=PROMPT, 
                         temperature=1.99, 
                         num_ctx=1000, 
                         num_predict=2000)

### YOU DONT NEED TO CONFIGURE ANYTHING ELSE FROM THIS POINT
# Send out to the model
time, response = model_req(payload=payload)
print(response)
if time: print(f'Time taken: {time}s')
# Out:
# {'model': 'llama3', 'prompt': 'create a SDLC requirements document focused on machine learning models', 'stream': False, 'options': {'temperature': 1.99, 'num_ctx': 1000, 'num_predict': 2000}}
# **Machine Learning Model SDLC Requirements Document**
#
# **Introduction**
#
# This document outlines the Software Development Life Cycle (SDLC) requirements for developing, deploying, and maintaining machine learning models. The goal of this process is to ensure that machine learning models are developed in a predictable, scalable, and maintainable manner.
#
# **Scope**
#
# The scope of this process includes all machine learning models developed within [Organization Name]. This includes, but is not limited to, predictive models, recommender systems, natural language processing models, and computer vision models.
#
# **Phases**
#
# The machine learning model SDLC consists of the following phases:
#
# 1. **Problem Definition**
# ...

# %%
##
## ZERO SHOT PROMPTING
##

from _pipeline import create_payload, model_req

#### (1) Adjust the inbounding  Prompt, simulating inbounding requests from users or other systems
MESSAGE = "create a SDLC requirements document focused on machine learning models"

#### (2) Adjust the Prompt Engineering Technique to be applied, simulating Workflow Templates
PROMPT = MESSAGE 

#### (3) Configure the Model request, simulating Workflow Orchestration
# Documentation: https://github.com/ollama/ollama/blob/main/docs/api.md
payload = create_payload(target="ollama",
                         model="llama3", 
                         prompt=PROMPT, 
                         temperature=1, 
                         num_ctx=10000, 
                         num_predict=2000)

### YOU DONT NEED TO CONFIGURE ANYTHING ELSE FROM THIS POINT
# Send out to the model
time, response = model_req(payload=payload)
print(response)
if time: print(f'Time taken: {time}s')
# Out:
# {'model': 'llama3', 'prompt': 'create a SDLC requirements document focused on machine learning models', 'stream': False, 'options': {'temperature': 1, 'num_ctx': 10000, 'num_predict': 2000}}
# Here is a sample Software Development Life Cycle (SDLC) Requirements Document focused on Machine Learning Models:
#
# **Document Title:** Machine Learning Model SDLC Requirements
#
# **Purpose:**
#
# The purpose of this document is to outline the software development life cycle (SDLC) requirements for developing and deploying machine learning models. This document aims to ensure that all stakeholders, including data scientists, engineers, and project managers, have a clear understanding of the processes and best practices required to develop high-quality machine learning models.
#
# **Scope:**
#
# This document applies to all projects involving the development and deployment of machine learning models.
#
# **SDLC Phases:**
#
# ...

# %%
##
## ZERO SHOT PROMPTING
##

from _pipeline import create_payload, model_req

#### (1) Adjust the inbounding  Prompt, simulating inbounding requests from users or other systems
MESSAGE = "create a SDLC requirements document focused on machine learning models"

#### (2) Adjust the Prompt Engineering Technique to be applied, simulating Workflow Templates
PROMPT = MESSAGE 

#### (3) Configure the Model request, simulating Workflow Orchestration
# Documentation: https://github.com/ollama/ollama/blob/main/docs/api.md
payload = create_payload(target="ollama",
                         model="llama3", 
                         prompt=PROMPT, 
                         temperature=1.33, 
                         num_ctx=10000, 
                         num_predict=2000)

### YOU DONT NEED TO CONFIGURE ANYTHING ELSE FROM THIS POINT
# Send out to the model
time, response = model_req(payload=payload)
print(response)
if time: print(f'Time taken: {time}s')
# Out:
# {'model': 'llama3', 'prompt': 'create a SDLC requirements document focused on machine learning models', 'stream': False, 'options': {'temperature': 1.33, 'num_ctx': 10000, 'num_predict': 2000}}
# Here is a sample SDLC (Software Development Life Cycle) Requirements Document focused on Machine Learning Models:
#
# **Document Title:** SDLC Requirements for Machine Learning Model Development
#
# **Document Number:** ML-001
#
# **Purpose:**
#
# This document outlines the software development life cycle (SDLC) requirements for machine learning model development at [Organization Name]. The goal is to ensure that machine learning models are developed, tested, and deployed in a controlled and transparent manner, while also meeting the needs of our customers and stakeholders.
#
# **Scope:**
#
# This SDLC applies to all machine learning model development projects within [Organization Name], including but not limited to:
#
# * Developing new machine learning models
# ...

# %%
##
## ZERO SHOT PROMPTING
##

from _pipeline import create_payload, model_req

#### (1) Adjust the inbounding  Prompt, simulating inbounding requests from users or other systems
MESSAGE = "create a SDLC requirements document focused on machine learning models"

#### (2) Adjust the Prompt Engineering Technique to be applied, simulating Workflow Templates
PROMPT = MESSAGE 

#### (3) Configure the Model request, simulating Workflow Orchestration
# Documentation: https://github.com/ollama/ollama/blob/main/docs/api.md
payload = create_payload(target="ollama",
                         model="llama3", 
                         prompt=PROMPT, 
                         temperature=1.66, 
                         num_ctx=10000, 
                         num_predict=2000)

### YOU DONT NEED TO CONFIGURE ANYTHING ELSE FROM THIS POINT
# Send out to the model
time, response = model_req(payload=payload)
print(response)
if time: print(f'Time taken: {time}s')
# Out:
# {'model': 'llama3', 'prompt': 'create a SDLC requirements document focused on machine learning models', 'stream': False, 'options': {'temperature': 1.66, 'num_ctx': 10000, 'num_predict': 2000}}
# Here is a sample SDLC (Software Development Life Cycle) Requirements Document focused on Machine Learning Models:
#
# **Machine Learning Model SDLC Requirements Document**
#
# **Introduction:**
# The purpose of this document is to outline the requirements for developing, testing, and deploying machine learning models within our organization. The goal is to ensure that these models are developed in a predictable, repeatable, and reliable manner, while also minimizing risk and ensuring compliance with relevant regulations.
#
# **Scope:**
# This document applies to all machine learning models developed or used by [Organization Name], including but not limited to:
#
# * Predictive models
# * Classification models
# * Regression models
# * Clustering models
# ...

# %%
##
## ZERO SHOT PROMPTING
##

from _pipeline import create_payload, model_req

#### (1) Adjust the inbounding  Prompt, simulating inbounding requests from users or other systems
MESSAGE = "create a SDLC requirements document focused on machine learning models"

#### (2) Adjust the Prompt Engineering Technique to be applied, simulating Workflow Templates
PROMPT = MESSAGE 

#### (3) Configure the Model request, simulating Workflow Orchestration
# Documentation: https://github.com/ollama/ollama/blob/main/docs/api.md
payload = create_payload(target="ollama",
                         model="llama3", 
                         prompt=PROMPT, 
                         temperature=1.99, 
                         num_ctx=10000, 
                         num_predict=2000)

### YOU DONT NEED TO CONFIGURE ANYTHING ELSE FROM THIS POINT
# Send out to the model
time, response = model_req(payload=payload)
print(response)
if time: print(f'Time taken: {time}s')
# Out:
# {'model': 'llama3', 'prompt': 'create a SDLC requirements document focused on machine learning models', 'stream': False, 'options': {'temperature': 1.99, 'num_ctx': 10000, 'num_predict': 2000}}
# Here is a sample SDLC (Software Development Life Cycle) Requirements Document focused on Machine Learning Models:
#
# **SDLC Requirements Document: Machine Learning Models**
#
# **Introduction**
# Machine learning models are complex systems that require careful planning, design, development, testing, and deployment. This document outlines the requirements for developing and deploying machine learning models as part of a Software Development Life Cycle (SDLC).
#
# **Scope**
# This SDLC is applicable to all machine learning model development projects within [Organization/Department].
#
# **Purpose**
# ...

# %%
##
## ZERO SHOT PROMPTING
##

from _pipeline import create_payload, model_req

#### (1) Adjust the inbounding  Prompt, simulating inbounding requests from users or other systems
MESSAGE = "create a SDLC requirements document focused on machine learning models"

#### (2) Adjust the Prompt Engineering Technique to be applied, simulating Workflow Templates
PROMPT = MESSAGE 

#### (3) Configure the Model request, simulating Workflow Orchestration
# Documentation: https://github.com/ollama/ollama/blob/main/docs/api.md
payload = create_payload(target="ollama",
                         model="llama3", 
                         prompt=PROMPT, 
                         temperature=1, 
                         num_ctx=100000, 
                         num_predict=2000)

### YOU DONT NEED TO CONFIGURE ANYTHING ELSE FROM THIS POINT
# Send out to the model
time, response = model_req(payload=payload)
print(response)
if time: print(f'Time taken: {time}s')
# Out:
# {'model': 'llama3', 'prompt': 'create a SDLC requirements document focused on machine learning models', 'stream': False, 'options': {'temperature': 1, 'num_ctx': 100000, 'num_predict': 2000}}
# **Machine Learning Models SDLC Requirements Document**
#
# **Introduction**
#
# The purpose of this document is to outline the software development life cycle (SDLC) requirements for developing and deploying machine learning models. This document provides a framework for ensuring that machine learning models are developed, tested, and deployed in a controlled and transparent manner.
#
# **Scope**
#
# This document applies to all machine learning model development projects within [Organization/Company]. It covers the SDLC process from concept to deployment, including data preparation, modeling, testing, validation, and monitoring.
#
# **Requirements**
#
# ### 1. Concept and Requirements Gathering
#
# ...

# %%
##
## ZERO SHOT PROMPTING
##

from _pipeline import create_payload, model_req

#### (1) Adjust the inbounding  Prompt, simulating inbounding requests from users or other systems
MESSAGE = "create a SDLC requirements document focused on machine learning models"

#### (2) Adjust the Prompt Engineering Technique to be applied, simulating Workflow Templates
PROMPT = MESSAGE 

#### (3) Configure the Model request, simulating Workflow Orchestration
# Documentation: https://github.com/ollama/ollama/blob/main/docs/api.md
payload = create_payload(target="ollama",
                         model="llama3", 
                         prompt=PROMPT, 
                         temperature=1.33, 
                         num_ctx=100000, 
                         num_predict=2000)

### YOU DONT NEED TO CONFIGURE ANYTHING ELSE FROM THIS POINT
# Send out to the model
time, response = model_req(payload=payload)
print(response)
if time: print(f'Time taken: {time}s')
# Out:
# {'model': 'llama3', 'prompt': 'create a SDLC requirements document focused on machine learning models', 'stream': False, 'options': {'temperature': 1.33, 'num_ctx': 100000, 'num_predict': 2000}}
# Here is a sample Software Development Life Cycle (SDLC) Requirements Document focused on Machine Learning Models:
#
# **Machine Learning Model SDLC Requirements**
#
# **Overview:**
# The purpose of this document is to outline the software development life cycle requirements for machine learning models at [Organization Name]. This SDLC will guide the development and deployment of machine learning models, ensuring that they meet the organization's quality, security, and performance standards.
#
# **Scope:**
# This SDLC applies to all machine learning model development projects within [Organization Name], including:
#
# * Data preparation and feature engineering
# * Model training and evaluation
# * Model deployment and integration
# * Model maintenance and updates
#
# **SDLC Phases:**
#
# ...

# %%
##
## ZERO SHOT PROMPTING
##

from _pipeline import create_payload, model_req

#### (1) Adjust the inbounding  Prompt, simulating inbounding requests from users or other systems
MESSAGE = "create a SDLC requirements document focused on machine learning models"

#### (2) Adjust the Prompt Engineering Technique to be applied, simulating Workflow Templates
PROMPT = MESSAGE 

#### (3) Configure the Model request, simulating Workflow Orchestration
# Documentation: https://github.com/ollama/ollama/blob/main/docs/api.md
payload = create_payload(target="ollama",
                         model="llama3", 
                         prompt=PROMPT, 
                         temperature=1.66, 
                         num_ctx=100000, 
                         num_predict=2000)

### YOU DONT NEED TO CONFIGURE ANYTHING ELSE FROM THIS POINT
# Send out to the model
time, response = model_req(payload=payload)
print(response)
if time: print(f'Time taken: {time}s')
# Out:
# {'model': 'llama3', 'prompt': 'create a SDLC requirements document focused on machine learning models', 'stream': False, 'options': {'temperature': 1.66, 'num_ctx': 100000, 'num_predict': 2000}}
# **Machine Learning Model Development SDLC Requirements Document**
#
# **Introduction:**
# This SDLC (Software Development Life Cycle) requirements document outlines the processes and guidelines for developing machine learning (ML) models. The purpose of this document is to provide a standardized framework for ML model development, ensuring consistency, quality, and efficiency across projects.
#
# **Scope:**
# This document applies to all ML model development projects within [Organization Name]. It covers the entire lifecycle of an ML project, from concept to deployment, including data preparation, model training, testing, validation, and maintenance.
#
# **Roles and Responsibilities:**
#
# ...

# %%
##
## ZERO SHOT PROMPTING
##

from _pipeline import create_payload, model_req

#### (1) Adjust the inbounding  Prompt, simulating inbounding requests from users or other systems
MESSAGE = "create a SDLC requirements document focused on machine learning models"

#### (2) Adjust the Prompt Engineering Technique to be applied, simulating Workflow Templates
PROMPT = MESSAGE 

#### (3) Configure the Model request, simulating Workflow Orchestration
# Documentation: https://github.com/ollama/ollama/blob/main/docs/api.md
payload = create_payload(target="ollama",
                         model="llama3", 
                         prompt=PROMPT, 
                         temperature=1.99, 
                         num_ctx=100000, 
                         num_predict=2000)

### YOU DONT NEED TO CONFIGURE ANYTHING ELSE FROM THIS POINT
# Send out to the model
time, response = model_req(payload=payload)
print(response)
if time: print(f'Time taken: {time}s')
# Out:
# {'model': 'llama3', 'prompt': 'create a SDLC requirements document focused on machine learning models', 'stream': False, 'options': {'temperature': 1.99, 'num_ctx': 100000, 'num_predict': 2000}}
# Here is a sample Software Development Life Cycle (SDLC) Requirements Document focused on Machine Learning Models:
#
# **Machine Learning Model Development Requirements**
#
# **Purpose:** This document outlines the requirements for developing machine learning models within the organization. It defines the process, roles, and responsibilities for creating and deploying AI/ML models that meet organizational needs.
#
# **Scope:** This document applies to all machine learning model development projects within the organization.
#
# **Definitions:**
#
# 1. **Machine Learning Model (MLM):** A software program that uses statistical or algorithmic methods to analyze data and make predictions or classify items.
# ...

# %%
#Create a Pandas DataFrame from the above data
import pandas as pd

zeroshot_df = pd.DataFrame({'Trial': [1, 1.33, 1.66, 1.99, 1, 1.33, 1.66, 1.99, 1, 1.33, 1.66, 1.99, 1, 1.33, 1.66, 1.99], 
'Temperature': [1, 1, 1, 1, 1.33, 1.33, 1.33, 1.33, 1.66, 1.66, 1.66, 1.66, 1.99, 1.99, 1.99, 1.99], 
'Context': [100, 100, 100, 100, 1000, 1000, 1000, 1, 10000, 10000, 10000, 10000, 100000, 100000, 100000, 100000], 
'Comprehensiveness Score': [8, 8, 8, 8, 9.5, 9, 8.5, 8, 9, 9.5, 8, 9.5, 9.5, 9.5, 9, 8.5], 
'Effectiveness Score': [9, 7.5, 7, 9, 9, 9, 8.5, 9, 8.5, 9, 9.5, 9, 9, 9, 8.5, 9], 
'Clarity Score': [8.5, 9, 9, 9, 9.5, 9.5, 9, 9, 9, 9, 9, 9.5, 9.5, 9, 9, 9], 
'Relevance Score': [9, 8.5, 8, 8, 10, 10, 9, 9, 9, 9.5, 9, 9.5, 9.5, 9.5, 9.5, 9.5], 
'Overall Score': [8.6, 8.1, 7.8, 8.5, 9.5, 9.3, 8.5, 8.5, 8.5, 9.2, 9.3, 9.4, 9.4, 9.4, 8.7, 8.7]})

# %%
import matplotlib.pyplot as plt


#Create 4 separate line charts one for each temperature
temp_charts = zeroshot_df.groupby('Temperature').mean()

# remove context variable from the dataframe
temp_charts = temp_charts.drop(['Context', 'Trial'], axis=1)

# Plot the data
temp_charts.plot(kind='line', marker='o', figsize=(10, 6))
plt.show()

#Create 4 separate line charts one for each context
temp_charts = zeroshot_df.groupby('Context').mean()

# remove temperature and trial variables from the dataframe
temp_charts = temp_charts.drop(['Temperature', 'Trial'], axis=1)

# Plot the data
temp_charts.plot(kind='line', marker='o', figsize=(10, 6))
plt.show()

# %% [markdown]
# ---
#
# ## How to improve it?
#
# * **Use Clear and Concise Instructions**: Be specific about the task and desired format.
#     * Bad Prompt: “Summarize this.”
#     * Good Prompt: “Summarize this paragraph in one sentence.”
# * **Add Context**: Providing background can help the model interpret ambiguous prompts better.
# * **Specify Output Format**: If a particular structure is needed, describe it in the instruction.
